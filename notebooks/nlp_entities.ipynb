# %% [markdown]
# # 🧠 NLP Entity Extraction with spaCy
#
# Extract named entities (like locations, dates, services) from escort profile descriptions.

# %%
import pandas as pd
import spacy
from collections import Counter
from spacy import displacy

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Load and prepare data
df = pd.read_csv("../data/processed/all_profiles.csv")
df["description"] = df["description"].fillna("").astype(str)

# Sample subset for performance
sample = df.sample(200, random_state=42).copy()
docs = list(nlp.pipe(sample["description"]))

# Extract named entities
sample["entities"] = [[(ent.text, ent.label_) for ent in doc.ents] for doc in docs]
sample[["title", "entities"]].head()
# Out:
#                                                   title  \
# 1239  Cock, Pussy & Butt models required - satisfy o...
# 1187             Required massage experienced personnel
# 560                                    M2M Massage Melb
# 767                     Nice to meet you, I am Keke, 23
# 714                                              Maddie
#
#                                                entities
# 1239                                                 []
# 1187  [(an hour, TIME), (3 to 4, CARDINAL), (ABN, OR...
# 560      [(Melbourne, GPE), (Employed Masseur, PERSON)]
# 767                                                  []
# 714               [(Fit Aussie, PERSON), (8, CARDINAL)]

# %% [markdown]
# ## 🔢 Most Common Entity Types

# %%
entity_counter = Counter()
for ents in sample["entities"]:
    entity_counter.update([label for _, label in ents])

pd.DataFrame(entity_counter.most_common(), columns=["Entity Type", "Count"])
# Out:
#     Entity Type  Count
# 0      CARDINAL    118
# 1          DATE    105
# 2        PERSON    101
# 3           ORG     87
# 4           GPE     64
# 5          TIME     29
# 6          NORP     27
# 7       PERCENT     14
# 8      QUANTITY     13
# 9       ORDINAL      8
# 10  WORK_OF_ART      6
# 11      PRODUCT      4
# 12          FAC      3
# 13        MONEY      3
# 14          LOC      3
# 15        EVENT      1
# 16     LANGUAGE      1

# %% [markdown]
# ## 📌 Example Entities

# %%
samples = []
for ents in sample["entities"]:
    for ent_text, ent_label in ents:
        if ent_label in {"GPE", "DATE", "MONEY", "PERSON"}:
            samples.append((ent_text, ent_label))
pd.DataFrame(samples[:25], columns=["Entity", "Label"])
# Out:
#                    Entity   Label
# 0                    3048    DATE
# 1               Melbourne     GPE
# 2        Employed Masseur  PERSON
# 3              Fit Aussie  PERSON
# 4                     don  PERSON
# 5                  Amanda  PERSON
# 6            Thai Ladyboy  PERSON
# 7              0414805956    DATE
# 8                   50 45    DATE
# 9              0432106848    DATE
# 10                  Linda  PERSON
# 11         Essendon North     GPE
# 12                  today    DATE
# 13                   Lisa  PERSON
# 14                  Japan     GPE
# 15           26 years old    DATE
# 16  Telegram Melodyxmarks  PERSON
# 17                 Monday    DATE
# 18                 Monday    DATE
# 19                Tuesday    DATE
# 20              Wednesday    DATE
# 21                   days    DATE
# 22                  Years    DATE
# 23               30 years    DATE
# 24       13O FULL SERVICE   MONEY

# %% [markdown]
# ## 🖼️ Visualize Entities in a Description

# %%
doc = docs[0]
displacy.render(doc, style="ent", jupyter=True)
# Out:
# /Users/mariaanthoniez/Documents/AI-agent-Transpulse/transpulse/lib/python3.10/site-packages/spacy/displacy/__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">If the ad is still up, then I am still looking! Hi there, I am looking for cock, pussy &amp; butt models who are comfortable with me taking self portraits next to their cock, pussy &amp;/or butt. Would like to take flaccid and erection cock shots and some touching involved. Photos will not require any…</div></span>
